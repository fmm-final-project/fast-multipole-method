# %% [markdown]
# # Conserved quantity

# %% [markdown]
# ## FMM

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import os
import pandas as pd

df = pd.read_csv("conservation/conservation_results_alpha10000000000.0_fmm.csv")
time = df["i"]*0.1/np.sqrt(1.25)
f = df["K"] + df["U"]
plt.plot(time, df["K"], label="Kinetic Energy")
plt.plot(time, df["U"], label="Potential Energy")
plt.plot(time, df["U"]+df["K"], label="Total Energy")
drift = abs((f.iloc[0] - f.iloc[-1]) / f.iloc[0])
plt.text(
    0.35, 0.5,
    f'Total energy drift error: {drift:.4f}',
    transform=plt.gca().transAxes,
    bbox=dict(facecolor='white', alpha=0.6, edgecolor='gray')
)
# plt.plot(time, 2 * df["K"]+df["U"], label="U+2K")
plt.xlabel('$t/t_\mathrm{dyn}$')
plt.ylabel('Energy')
plt.title('Plummer model')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
time = df["i"] * 0.1 / np.sqrt(1.25)
f = -2 * df["K"] / df["U"]

# 計算指標
drift = abs((f.iloc[0] - f.iloc[-1]) / f.iloc[0])
rms_error = np.sqrt(np.mean((f - 1) ** 2))

# 繪圖
plt.axhline(y=1, color='r', linestyle='--', label='Ideal')
plt.plot(time, f, label="-2<T>/<V>")
plt.xlabel('$t/t_\mathrm{dyn}$')
plt.ylabel('ratio')
plt.title('Plummer model - Virial theorem')
plt.legend()
plt.grid(True)

# 顯示誤差資訊
plt.text(
    0.025, 0.74,
    f'drift error: {drift:.4f}\nRMS error: {rms_error:.4f}',
    transform=plt.gca().transAxes,
    bbox=dict(facecolor='white', alpha=0.6, edgecolor='gray')
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Tree

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import os
import pandas as pd

df = pd.read_csv("conservation/conservation_results_alpha10000000000.0_tree.csv")
time = df["i"]*0.1/np.sqrt(1.25)
f = df["K"] + df["U"]
plt.plot(time, df["K"], label="Kinetic Energy")
plt.plot(time, df["U"], label="Potential Energy")
plt.plot(time, df["U"]+df["K"], label="Total Energy")
drift = abs((f.iloc[0] - f.iloc[-1]) / f.iloc[0])
plt.text(
    0.1, 0.28,
    f'Total energy drift error: {drift:.4f}',
    transform=plt.gca().transAxes,
    bbox=dict(facecolor='white', alpha=0.6, edgecolor='gray')
)
# plt.plot(time, 2 * df["K"]+df["U"], label="U+2K")
plt.xlabel('$t/t_\mathrm{dyn}$')
plt.ylabel('Energy')
plt.title('Plummer model')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
time = df["i"] * 0.1 / np.sqrt(1.25)
f = -2 * df["K"] / df["U"]

# 計算指標
drift = abs((f.iloc[0] - f.iloc[-1]) / f.iloc[0])
rms_error = np.sqrt(np.mean((f - 1) ** 2))

# 繪圖
plt.axhline(y=1, color='r', linestyle='--', label='Ideal')
plt.plot(time, f, label="-2<T>/<V>")
plt.xlabel('$t/t_\mathrm{dyn}$')
plt.ylabel('ratio')
plt.title('Plummer model - Virial theorem')
plt.legend()
plt.grid(True)

# 顯示誤差資訊
plt.text(
    0.025, 0.74,
    f'drift error: {drift:.4f}\nRMS error: {rms_error:.4f}',
    transform=plt.gca().transAxes,
    bbox=dict(facecolor='white', alpha=0.6, edgecolor='gray')
)

plt.tight_layout()
plt.show()

# %%
plt.title('Plummer model - Escape Particles')
time = df["i"]*0.1/np.sqrt(1.25)
plt.plot(time, df["Ne"], label="Number of escape particles")
plt.legend()
plt.xlabel('$t/t_\mathrm{dyn}$')
plt.ylabel('Number of escape particles')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.title(r'Plummer model - $p_x$')
f = df["Px"]
time = df["i"]*0.1/np.sqrt(1.25)
drift = abs((f.iloc[0] - f.iloc[-1]) / f.iloc[0])
rms_error = np.sqrt(np.mean((f - f.iloc[0]) ** 2))

plt.plot(time, df["Px"], label=r"$p_x$")
plt.xlabel('$t/t_\mathrm{dyn}$')
plt.ylabel('Total Momentum (x)')
plt.text(
    0.71, 0.8,
    f'drift error: {drift:.4f}\nRMS error: {rms_error:.4f}',
    transform=plt.gca().transAxes,
    bbox=dict(facecolor='white', alpha=0.6, edgecolor='gray')
)
plt.legend(loc='upper right')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Naive

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import os
import pandas as pd

df = pd.read_csv("conservation/conservation_results_alpha10000000000.0_naive.csv")
time = df["i"]*0.1/np.sqrt(1.25)
f = df["K"] + df["U"]
plt.plot(time, df["K"], label="Kinetic Energy")
plt.plot(time, df["U"], label="Potential Energy")
plt.plot(time, df["U"]+df["K"], label="Total Energy")
drift = abs((f.iloc[0] - f.iloc[-1]) / f.iloc[0])
plt.text(
    0.1, 0.28,
    f'Total energy drift error: {drift:.4f}',
    transform=plt.gca().transAxes,
    bbox=dict(facecolor='white', alpha=0.6, edgecolor='gray')
)
# plt.plot(time, 2 * df["K"]+df["U"], label="U+2K")
plt.xlabel('$t/t_\mathrm{dyn}$')
plt.ylabel('Energy')
plt.title('Plummer model')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
time = df["i"] * 0.1 / np.sqrt(1.25)
f = -2 * df["K"] / df["U"]

# 計算指標
drift = abs((f.iloc[0] - f.iloc[-1]) / f.iloc[0])
rms_error = np.sqrt(np.mean((f - 1) ** 2))

# 繪圖
plt.axhline(y=1, color='r', linestyle='--', label='Ideal')
plt.plot(time, f, label="-2<T>/<V>")
plt.xlabel('$t/t_\mathrm{dyn}$')
plt.ylabel('ratio')
plt.title('Plummer model - Virial theorem')
plt.legend()
plt.grid(True)

# 顯示誤差資訊
plt.text(
    0.025, 0.74,
    f'drift error: {drift:.4f}\nRMS error: {rms_error:.4f}',
    transform=plt.gca().transAxes,
    bbox=dict(facecolor='white', alpha=0.6, edgecolor='gray')
)

plt.tight_layout()
plt.show()

# %%
plt.title('Plummer model - Escape Particles')
time = df["i"]*0.1/np.sqrt(1.25)
plt.plot(time, df["Ne"], label="Number of escape particles")
plt.legend()
plt.xlabel('$t/t_\mathrm{dyn}$')
plt.ylabel('Number of escape particles')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.title(r'Plummer model - $p_x$')
f = df["Px"]
time = df["i"]*0.1/np.sqrt(1.25)
drift = abs((f.iloc[0] - f.iloc[-1]) / f.iloc[0])
rms_error = np.sqrt(np.mean((f - f.iloc[0]) ** 2))

plt.plot(time, df["Px"], label=r"$p_x$")
plt.xlabel('$t/t_\mathrm{dyn}$')
plt.ylabel('Total Momentum (x)')
plt.text(
    0.71, 0.8,
    f'drift error: {drift:.4f}\nRMS error: {rms_error:.4f}',
    transform=plt.gca().transAxes,
    bbox=dict(facecolor='white', alpha=0.6, edgecolor='gray')
)
plt.legend(loc='upper right')
plt.grid(True)
plt.tight_layout()
plt.show()
